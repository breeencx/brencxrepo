# %%
import math
import numpy as np
from math import *
import scipy as sp

# %%
x0=1
y0=1


def f(a,b,x,y):
    x0= x
    y0= y
    y= b/(a+(x0**2))
    x= y0*(a+(x0**2))
    return x,y
a=1
b=2

f1(a,b,x0,y0)

for n in range (70):
    x,y = f(a, b, x, y)
    print (n,x,y)
# Out:
# 0 2.0 0.4
# 1 2.0 0.4
# 2 2.0 0.4
# 3 2.0 0.4
# 4 2.0 0.4
# 5 2.0 0.4
# 6 2.0 0.4
# 7 2.0 0.4
# 8 2.0 0.4
# 9 2.0 0.4
# 10 2.0 0.4
# 11 2.0 0.4
# 12 2.0 0.4
# 13 2.0 0.4
# 14 2.0 0.4
# 15 2.0 0.4
# 16 2.0 0.4
# 17 2.0 0.4
# 18 2.0 0.4
# 19 2.0 0.4
# 20 2.0 0.4
# 21 2.0 0.4
# 22 2.0 0.4
# 23 2.0 0.4
# 24 2.0 0.4
# 25 2.0 0.4
# 26 2.0 0.4
# 27 2.0 0.4
# 28 2.0 0.4
# 29 2.0 0.4
# 30 2.0 0.4
# 31 2.0 0.4
# 32 2.0 0.4
# 33 2.0 0.4
# 34 2.0 0.4
# 35 2.0 0.4
# 36 2.0 0.4
# 37 2.0 0.4
# 38 2.0 0.4
# 39 2.0 0.4
# 40 2.0 0.4
# 41 2.0 0.4
# 42 2.0 0.4
# 43 2.0 0.4
# 44 2.0 0.4
# 45 2.0 0.4
# 46 2.0 0.4
# 47 2.0 0.4
# 48 2.0 0.4
# 49 2.0 0.4
# 50 2.0 0.4
# 51 2.0 0.4
# 52 2.0 0.4
# 53 2.0 0.4
# 54 2.0 0.4
# 55 2.0 0.4
# 56 2.0 0.4
# 57 2.0 0.4
# 58 2.0 0.4
# 59 2.0 0.4
# 60 2.0 0.4
# 61 2.0 0.4
# 62 2.0 0.4
# 63 2.0 0.4
# 64 2.0 0.4
# 65 2.0 0.4
# 66 2.0 0.4
# 67 2.0 0.4
# 68 2.0 0.4
# 69 2.0 0.4

# %%
# Out:
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
# 2.0 0.4
