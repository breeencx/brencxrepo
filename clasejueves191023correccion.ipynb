# %%
import math
import numpy as np
from math import *
import scipy as sp

# %%
x=1
y=1
a=1
b=2


def f(a,b,x,y):
    x0= x
    y0= y
    y= b/(a+(x0**2))
    x= y0*(a+(x0**2))
    return x,y

# f(a,b,x0,y0)

for n in range (50):
    x0= x
    y0= y
    y= b/(a+(x0**2))
    x= y0*(a+(x0**2))
#     x,y = f(a, b, x, y)
    print (n,x,y)
# Out:
# 0 2 1.0
# 1 5.0 0.4
# 2 10.4 0.07692307692307693
# 3 8.396923076923079 0.018321729571271525
# 4 1.310156049097899 0.0279687745347386
# 5 0.0759774241902131 0.7362390824073594
# 6 0.7404890733011719 1.988521124626821
# 7 3.0788751163466825 1.291719247766276
# 8 13.536535665652755 0.19084931029197522
# 9 35.161656645088655 0.010855535745562367
# 10 13.432011374622395 0.0016163678607467738
# 11 0.2932397270847742 0.011024207919000618
# 12 0.011972174459708588 1.841638368385246
# 13 1.8419023358662185 1.9997133751601999
# 14 8.783949400259472 0.45531076832048456
# 15 35.58607297317904 0.02558926738916367
# 16 32.431033721243125 0.001578072879767756
# 17 1.661350860079516 0.0018997466672298542
# 18 0.007143212139370495 0.5319026315232105
# 19 0.5319297721101206 1.9998979542475976
# 20 2.5657676453894274 1.5589080779324092
# 21 11.821455008110393 0.263742166571354
# 22 37.120865576687 0.01420991469212894
# 23 19.59488493909098 0.0014503698017415505
# ...

# %%
#ejercico 4 b)
x=5
y=2
a=1
b=2


for n in range (70):
    x0= x
    y0= y
    
    y= x0/(a+(x0**2))
    x= np.sqrt((b/y)-a)

    print (n,x,y)
# Out:
# 0 3.065941943351178 0.19230769230769232
# 1 2.4050388686580098 0.2948021099376133
# 2 2.1544523965803 0.3545052664811758
# 3 2.0584496424312717 0.38188236048535357
# 4 2.022005020257384 0.393042804195943
# 5 2.008264740565524 0.3973672616301183
# 6 2.003101125020025 0.3990093302934211
# 7 2.0011631837638766 0.3996280192021194
# 8 2.000436230850242 0.39986043961388246
# 9 2.0001635917692653 0.39994765534365795
# 10 2.000061347645096 0.39998036941593346
# 11 2.000023005469812 0.3999926383428076
# 12 2.0000086270656507 0.39999723935209075
# 13 2.000003235151654 0.3999989647533127
# 14 2.0000012131821565 0.39999961178196897
# 15 2.0000004549433488 0.39999985441816477
# 16 2.0000001706037613 0.39999994540680145
# 17 2.0000000639764113 0.39999997952754907
# 18 2.0000000239911544 0.3999999923228307
# 19 2.000000008996683 0.39999999712106143
# 20 2.000000003373756 0.39999999892039806
# 21 2.000000001265158 0.3999999995951493
# 22 2.0000000004744343 0.399999999848181
# ...
